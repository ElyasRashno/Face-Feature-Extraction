# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # FaceDetection

# %% [markdown]
# - with high-level API (WebcamFaceDetector)

# %%
from facelib import WebcamFaceDetector

detector = WebcamFaceDetector()
# Out:
# loading ...
# from FaceDetector: weights loaded

# %%
# please wait: it shows a window  
detector.run()
# Out:
# type q for exit
# [ WARN:0] global /tmp/pip-req-build-947ayiyu/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index

# %% [markdown]
# - with low-level API(FaceDetector)

# %%
import matplotlib.pyplot as plt
from facelib import FaceDetector

img = plt.imread('facelib/imgs/face_rec.jpg')
detector = FaceDetector()
# Out:
# from FaceDetector: weights loaded

# %%
faces, boxes, scores, landmarks = detector.detect_align(img)
plt.imshow(faces.cpu()[0]);

# %% [markdown]
# # AgeGenderEstimator

# %% [markdown]
# - with high-level API (WebcamAgeGenderEstimator)

# %%
from facelib import WebcamAgeGenderEstimator

estimator = WebcamAgeGenderEstimator()
# Out:
# loading ...
# from FaceDetector: weights loaded
# from AgeGenderEstimator: weights loaded

# %%
# please wait: it shows a window  
estimator.run()
# Out:
# type q for exit
# [ WARN:0] global /tmp/pip-req-build-947ayiyu/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index

# %% [markdown]
# - with low-level API(FaceDetector)

# %%
import matplotlib.pyplot as plt
from facelib import AgeGenderEstimator, FaceDetector

img = plt.imread('facelib/imgs/face_rec.jpg')
face_detector = FaceDetector()
age_gender_detector = AgeGenderEstimator()
#print(age_gender_detector)
# Out:
# from FaceDetector: weights loaded
# from AgeGenderEstimator: weights loaded

# %%
faces, boxes, scores, landmarks = face_detector.detect_align(img)
genders, ages = age_gender_detector.detect(faces)
print(genders, ages)
# Out:
# ['Male', 'Male'] [12, 11]

# %% [markdown]
# # FacialExpression

# %% [markdown]
# - with high-level API (WebcamAgeGenderEstimator)

# %%
from facelib import WebcamEmotionDetector

detector = WebcamEmotionDetector()
# Out:
# loading ...
# from FaceDetector: weights loaded
# from EmotionDetector: weights loaded

# %%
# please wait: it shows a window
detector.run()
# Out:
# type q for exit
# [ WARN:0] global /tmp/pip-req-build-947ayiyu/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index

# %% [markdown]
# - with low-level API(FaceDetector)

# %%
import matplotlib.pyplot as plt
from facelib import FaceDetector, EmotionDetector

img = plt.imread('facelib/imgs/face_rec.jpg')
face_detector = FaceDetector(face_size=(224, 224))
emotion_detector = EmotionDetector()
# Out:
# from FaceDetector: weights loaded
# from EmotionDetector: weights loaded

# %%
faces, boxes, scores, landmarks = face_detector.detect_align(img)
list_of_emotions, probab = emotion_detector.detect_emotion(faces)
print(list_of_emotions)
# Out:
# ['happy' 'happy']

# %% [markdown]
# # Add New Person

# %%
from facelib import add_from_webcam

add_from_webcam(person_name='sajjad')
# Out:
# loading ...
# for exit: use q keyword
# from FaceDetector: weights loaded
# type q for exit
# images saved in this path:  /home/user/Desktop/face-biometric-server/src/models/FaceLib-master/facelib/InsightFace/models/data/facebank/sajjad
# [ WARN:0] global /tmp/pip-req-build-947ayiyu/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index

# %%
from facelib import add_from_folder

add_from_folder(person_name='sajjad', folder_path='./test/')
# Out:
# only a face in each image and all image from the same person
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21588/1143967869.py in <module>
#       1 from facelib import add_from_folder
#       2
# ----> 3 add_from_folder(person_name='sajjad', folder_path='./test/')
#       4
#
# ~/Desktop/face-biometric-server/src/models/FaceLib-master/facelib/InsightFace/add_face.py in add_from_folder(folder_path, person_name)
#      63     dir_path = Path(folder_path)
#      64     if not dir_path.is_dir():
# ---> 65         exit('dir does not exists !!')
#      66
#      67     # create facebank folder if is not exists
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # FaceRecognition

# %% [markdown]
# - with high-level API (WebcamVerify)

# %%
from facelib import WebcamVerify

verifier = WebcamVerify()

# %%
# please wait: it shows a window
verifier.run()

# %% [markdown]
# - with low-level API(FaceRecognizer)

# %%
import matplotlib.pyplot as plt
from facelib import FaceRecognizer, FaceDetector
from facelib import update_facebank, load_facebank, special_draw, get_config

conf = get_config()
detector = FaceDetector()
face_rec = FaceRecognizer(conf)
face_rec.model.eval()

update = True
if update:
    targets, names = update_facebank(conf, face_rec.model, detector)
else:
    targets, names = load_facebank(conf)
# Out:
# from FaceDetector: weights loaded
# from FaceRecognizer: MobileFaceNet Loaded
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_21588/1681728873.py in <module>
#      10 update = True
#      11 if update:
# ---> 12     targets, names = update_facebank(conf, face_rec.model, detector)
#      13 else:
#      14     targets, names = load_facebank(conf)
#
# ~/Desktop/face-biometric-server/src/models/FaceLib-master/facelib/InsightFace/models/utils.py in update_facebank(conf, model, detector, tta)
#      53             faces.append(face)
#      54
# ---> 55         faces = torch.cat(faces)
#      56         if len(faces.shape) <= 3:
#      57             continue
#
# NotImplementedError: There were no tensor arguments to this function (e.g., you passed an empty list of Tensors), but no fallback function is registered for schema aten::_cat.  This usually means that this function requires a non-empty list of Tensors, or that you (the operator writer) forgot to register a fallback function.  Available functions are [CPU, CUDA, QuantizedCPU, BackendSelect, Named, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradXLA, UNKNOWN_TENSOR_TYPE_ID, AutogradMLC, AutogradHPU, AutogradNestedTensor, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, Tracer, Autocast, Batched, VmapMode].
#
# CPU: registered at /pytorch/build/aten/src/ATen/RegisterCPU.cpp:16286 [kernel]
# CUDA: registered at /pytorch/build/aten/src/ATen/RegisterCUDA.cpp:20674 [kernel]
# QuantizedCPU: registered at /pytorch/build/aten/src/ATen/RegisterQuantizedCPU.cpp:1025 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:60 [backend fallback]
# AutogradOther: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradCPU: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradCUDA: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradXLA: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# UNKNOWN_TENSOR_TYPE_ID: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradMLC: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradHPU: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradNestedTensor: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradPrivateUse1: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradPrivateUse2: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# AutogradPrivateUse3: registered at /pytorch/torch/csrc/autograd/generated/VariableType_2.cpp:9928 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/generated/TraceType_2.cpp:9621 [kernel]
# Autocast: registered at /pytorch/aten/src/ATen/autocast_mode.cpp:259 [kernel]
# Batched: registered at /pytorch/aten/src/ATen/BatchingRegistrations.cpp:1019 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]

# %%
img = plt.imread('facelib/imgs/face_rec.jpg')

faces, boxes, scores, landmarks = detector.detect_align(img)
results, score = face_rec.infer(conf, faces, targets)
names[results.cpu()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21588/2384387621.py in <module>
#       1 img = plt.imread('facelib/imgs/face_rec.jpg')
#       2
# ----> 3 faces, boxes, scores, landmarks = detector.detect_align(img)
#       4 results, score = face_rec.infer(conf, faces, targets)
#       5 names[results.cpu()]
#
# AttributeError: 'WebcamEmotionDetector' object has no attribute 'detect_align'
